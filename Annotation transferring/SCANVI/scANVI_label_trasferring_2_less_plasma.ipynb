# %% [markdown]
# ### Notebook for the label transfer of Reference small dataset (GCA+stem cells) to rest of GCA using `scANVI`
#
# - **Developed by:** Anna Maguxa
# - **Institute of Computational Biology - Computational Health Department - Helmholtz Munich**
# - 17th February 2022
#
# The main difference of this notebook with other scANVI_label_transferring_on_GCA.ipynb is that in this notebook another reference dataset is used, which has less plasma cells.

# %% [markdown]
# ### Import required modules

# %%
import scvi
import anndata
import warnings
import numpy as np
import scanpy as sc
import pandas as pd
import matplotlib.pyplot as plt
# Out:
# Global seed set to 0
# /home/icb/anna.maguza/miniconda3/envs/scvi_env/lib/python3.9/site-packages/pytorch_lightning/utilities/warnings.py:53: LightningDeprecationWarning: pytorch_lightning.utilities.warnings.rank_zero_deprecation has been deprecated in v1.6 and will be removed in v1.8. Use the equivalent function from the pytorch_lightning.utilities.rank_zero module instead.
#   new_rank_zero_deprecation(
# /home/icb/anna.maguza/miniconda3/envs/scvi_env/lib/python3.9/site-packages/pytorch_lightning/utilities/warnings.py:58: LightningDeprecationWarning: The `pytorch_lightning.loggers.base.rank_zero_experiment` is deprecated in v1.7 and will be removed in v1.9. Please use `pytorch_lightning.loggers.logger.rank_zero_experiment` instead.
#   return new_rank_zero_deprecation(*args, **kwargs)

# %% [markdown]
# ### Set up working environment

# %%
# %matplotlib inline

# %%
sc.settings.verbosity = 3
sc.logging.print_versions()
sc.settings.set_figure_params(dpi = 180, color_map = 'magma_r', dpi_save = 300, vector_friendly = True, format = 'svg')
# Out:
# -----
# anndata     0.8.0
# scanpy      1.9.1
# -----
# PIL                 9.2.0
# absl                NA
# asttokens           NA
# attr                22.1.0
# backcall            0.2.0
# beta_ufunc          NA
# binom_ufunc         NA
# bottleneck          1.3.5
# brotli              NA
# certifi             2022.09.24
# cffi                1.15.1
# charset_normalizer  2.1.1
# chex                0.1.5
# contextlib2         NA
# cycler              0.10.0
# cython_runtime      NA
# dateutil            2.8.2
# debugpy             1.6.3
# decorator           5.1.1
# defusedxml          0.7.1
# deprecate           0.3.2
# docrep              0.3.2
# entrypoints         0.4
# executing           1.2.0
# flax                0.6.2
# fsspec              2022.11.0
# google              NA
# h5py                3.7.0
# hypergeom_ufunc     NA
# idna                3.4
# ipykernel           6.17.1
# ipython_genutils    0.2.0
# ipywidgets          8.0.2
# jax                 0.3.25
# jaxlib              0.3.25
# jedi                0.18.2
# joblib              1.2.0
# jupyter_server      1.23.3
# kiwisolver          1.4.4
# llvmlite            0.39.1
# matplotlib          3.6.2
# matplotlib_inline   0.1.6
# ml_collections      NA
# mpl_toolkits        NA
# msgpack             1.0.4
# mudata              0.2.1
# multipledispatch    0.6.0
# natsort             8.2.0
# nbinom_ufunc        NA
# ncf_ufunc           NA
# numba               0.56.4
# numexpr             2.8.4
# numpy               1.23.5
# numpyro             0.10.1
# nvidia              NA
# opt_einsum          v3.3.0
# optax               0.1.4
# packaging           21.3
# pandas              1.5.1
# parso               0.8.3
# pexpect             4.8.0
# pickleshare         0.7.5
# pkg_resources       NA
# platformdirs        2.5.2
# prompt_toolkit      3.0.33
# psutil              5.9.4
# ptyprocess          0.7.0
# pure_eval           0.2.2
# pydev_ipython       NA
# pydevconsole        NA
# pydevd              2.8.0
# pydevd_file_utils   NA
# pydevd_plugins      NA
# pydevd_tracing      NA
# pygments            2.13.0
# pyparsing           3.0.9
# pyro                1.8.3
# pytorch_lightning   1.7.7
# pytz                2022.6
# requests            2.28.1
# rich                NA
# scipy               1.9.3
# scvi                0.19.0
# session_info        1.0.0
# setuptools          65.5.1
# six                 1.16.0
# sklearn             1.1.3
# socks               1.7.1
# stack_data          0.6.1
# tensorboard         2.11.0
# threadpoolctl       3.1.0
# toolz               0.12.0
# torch               1.12.1.post201
# torchmetrics        0.10.3
# torchvision         0.13.0a0+8069656
# tornado             6.2
# tqdm                4.64.1
# traitlets           5.5.0
# tree                0.1.7
# typing_extensions   NA
# unicodedata2        NA
# urllib3             1.26.13
# wcwidth             0.2.5
# yaml                6.0
# zipp                NA
# zmq                 24.0.1
# zoneinfo            NA
# -----
# IPython             8.6.0
# jupyter_client      7.4.7
# jupyter_core        5.0.0
# jupyterlab          3.5.0
# notebook            6.5.2
# -----
# Python 3.9.15 | packaged by conda-forge | (main, Nov 22 2022, 15:55:03) [GCC 10.4.0]
# Linux-3.10.0-1160.71.1.el7.x86_64-x86_64-with-glibc2.17
# -----
# Session information updated at 2023-02-22 18:40

# %%
warnings.simplefilter(action = 'ignore')
scvi.settings.seed = 1712
# %config InlineBackend.print_figure_kwargs = {'facecolor' : "w"}
# %config InlineBackend.figure_format = 'retina'
# Out:
# Global seed set to 1712

# %%
arches_params = dict(
    use_layer_norm = "both",
    use_batch_norm = "none",
    encode_covariates = True,
    dropout_rate = 0.2,
    n_layers = 2,
)

# %% [markdown]
# ### Read in Reference object

# %%
reference_input = '/lustre/groups/talaveralopez/workspace/anna.maguza/Processed_datasets/expi_map/Reference_map_subset_after_geosketch2_less_plasma.h5ad'
reference_output = '/lustre/groups/talaveralopez/workspace/anna.maguza/Processed_datasets/expi_map/Reference_map_subset_after_geosketch_output.h5ad'

# %%
reference = sc.read_h5ad(reference_input)
reference.X
# Out:
# <116562x40144 sparse matrix of type '<class 'numpy.float32'>'
# 	with 238026331 stored elements in Compressed Sparse Row format>

# %%
reference.obs
# Out:
#                                                          UniqueCell_ID  \
# cell_id
# AACACGTTCTTGCATT_Ileum-1_Stem Cell  AACACGTTCTTGCATT_Ileum-1_Stem Cell
# AACCGCGCATGAAGTA_Ileum-1_Stem Cell  AACCGCGCATGAAGTA_Ileum-1_Stem Cell
# AACTCAGAGCGATCCC_Ileum-1_Stem Cell  AACTCAGAGCGATCCC_Ileum-1_Stem Cell
# AACTCCCTCTCAACTT_Ileum-1_Stem Cell  AACTCCCTCTCAACTT_Ileum-1_Stem Cell
# AACTCTTAGCTTCGCG_Ileum-1_Stem Cell  AACTCTTAGCTTCGCG_Ileum-1_Stem Cell
# ...                                                                ...
# TTTGTCAGTAAGGATT-1-4918STDY7714150                                 nan
# TTTGTCAGTAGAGGAA-1-4918STDY7714150                                 nan
# TTTGTCAGTCTAGAGG-1-4918STDY7714150                                 nan
# TTTGTCAGTTGATTGC-1-4918STDY7714150                                 nan
# TTTGTCATCAATCTCT-1-4918STDY7714150                                 nan
#
#                                              Sample_ID    CellType  \
# cell_id
# AACACGTTCTTGCATT_Ileum-1_Stem Cell             Ileum-1   Stem Cell
# AACCGCGCATGAAGTA_Ileum-1_Stem Cell             Ileum-1   Stem Cell
# AACTCAGAGCGATCCC_Ileum-1_Stem Cell             Ileum-1   Stem Cell
# AACTCCCTCTCAACTT_Ileum-1_Stem Cell             Ileum-1   Stem Cell
# AACTCTTAGCTTCGCG_Ileum-1_Stem Cell             Ileum-1   Stem Cell
# ...                                                ...         ...
# TTTGTCAGTAAGGATT-1-4918STDY7714150  T036-TIL-SC-EPCAMP  Epithelial
# TTTGTCAGTAGAGGAA-1-4918STDY7714150  T036-TIL-SC-EPCAMP  Epithelial
# TTTGTCAGTCTAGAGG-1-4918STDY7714150  T036-TIL-SC-EPCAMP  Epithelial
# TTTGTCAGTTGATTGC-1-4918STDY7714150  T036-TIL-SC-EPCAMP  Epithelial
# TTTGTCATCAATCTCT-1-4918STDY7714150  T036-TIL-SC-EPCAMP  Epithelial
#
#                                         Study_name          Diagnosis  Age  \
# cell_id
# AACACGTTCTTGCATT_Ileum-1_Stem Cell            Wang      Healthy adult  nan
# AACCGCGCATGAAGTA_Ileum-1_Stem Cell            Wang      Healthy adult  nan
# AACTCAGAGCGATCCC_Ileum-1_Stem Cell            Wang      Healthy adult  nan
# AACTCCCTCTCAACTT_Ileum-1_Stem Cell            Wang      Healthy adult  nan
# AACTCTTAGCTTCGCG_Ileum-1_Stem Cell            Wang      Healthy adult  nan
# ...                                            ...                ...  ...
# TTTGTCAGTAAGGATT-1-4918STDY7714150  Gut Cell Atlas  Pediatric healthy    4
# TTTGTCAGTAGAGGAA-1-4918STDY7714150  Gut Cell Atlas  Pediatric healthy    4
# TTTGTCAGTCTAGAGG-1-4918STDY7714150  Gut Cell Atlas  Pediatric healthy    4
# TTTGTCAGTTGATTGC-1-4918STDY7714150  Gut Cell Atlas  Pediatric healthy    4
# TTTGTCATCAATCTCT-1-4918STDY7714150  Gut Cell Atlas  Pediatric healthy    4
#
#                                    Region code   Fraction Gender  10X  ...  \
# cell_id                                                                ...
# AACACGTTCTTGCATT_Ileum-1_Stem Cell         nan        nan    nan  nan  ...
# AACCGCGCATGAAGTA_Ileum-1_Stem Cell         nan        nan    nan  nan  ...
# AACTCAGAGCGATCCC_Ileum-1_Stem Cell         nan        nan    nan  nan  ...
# AACTCCCTCTCAACTT_Ileum-1_Stem Cell         nan        nan    nan  nan  ...
# AACTCTTAGCTTCGCG_Ileum-1_Stem Cell         nan        nan    nan  nan  ...
# ...                                        ...        ...    ...  ...  ...
# TTTGTCAGTAAGGATT-1-4918STDY7714150         TIL  SC-EPCAMP      M   3'  ...
# TTTGTCAGTAGAGGAA-1-4918STDY7714150         TIL  SC-EPCAMP      M   3'  ...
# TTTGTCAGTCTAGAGG-1-4918STDY7714150         TIL  SC-EPCAMP      M   3'  ...
# TTTGTCAGTTGATTGC-1-4918STDY7714150         TIL  SC-EPCAMP      M   3'  ...
# TTTGTCATCAATCTCT-1-4918STDY7714150         TIL  SC-EPCAMP      M   3'  ...
#
#                                          doublet_scores predicted_doublets  \
# cell_id
# AACACGTTCTTGCATT_Ileum-1_Stem Cell                  nan                nan
# AACCGCGCATGAAGTA_Ileum-1_Stem Cell                  nan                nan
# AACTCAGAGCGATCCC_Ileum-1_Stem Cell                  nan                nan
# AACTCCCTCTCAACTT_Ileum-1_Stem Cell                  nan                nan
# AACTCTTAGCTTCGCG_Ileum-1_Stem Cell                  nan                nan
# ...                                                 ...                ...
# TTTGTCAGTAAGGATT-1-4918STDY7714150  0.04441988950276243              False
# TTTGTCAGTAGAGGAA-1-4918STDY7714150  0.11661683041435288              False
# TTTGTCAGTCTAGAGG-1-4918STDY7714150  0.11661683041435288              False
# TTTGTCAGTTGATTGC-1-4918STDY7714150  0.08832698302736401              False
# TTTGTCATCAATCTCT-1-4918STDY7714150  0.06640181611804766              False
#
#                                     Age_group Integrated_05 total_counts_ribo  \
# cell_id
# AACACGTTCTTGCATT_Ileum-1_Stem Cell        nan           nan               nan
# AACCGCGCATGAAGTA_Ileum-1_Stem Cell        nan           nan               nan
# AACTCAGAGCGATCCC_Ileum-1_Stem Cell        nan           nan               nan
# AACTCCCTCTCAACTT_Ileum-1_Stem Cell        nan           nan               nan
# AACTCTTAGCTTCGCG_Ileum-1_Stem Cell        nan           nan               nan
# ...                                       ...           ...               ...
# TTTGTCAGTAAGGATT-1-4918STDY7714150  Pediatric    Enterocyte             502.0
# TTTGTCAGTAGAGGAA-1-4918STDY7714150  Pediatric    Enterocyte             214.0
# TTTGTCAGTCTAGAGG-1-4918STDY7714150  Pediatric    Enterocyte             758.0
# TTTGTCAGTTGATTGC-1-4918STDY7714150  Pediatric    Enterocyte             157.0
# TTTGTCATCAATCTCT-1-4918STDY7714150  Pediatric    Enterocyte             257.0
#
#                                     Location n_counts percent_mito  \
# cell_id
# AACACGTTCTTGCATT_Ileum-1_Stem Cell       nan      nan          nan
# AACCGCGCATGAAGTA_Ileum-1_Stem Cell       nan      nan          nan
# AACTCAGAGCGATCCC_Ileum-1_Stem Cell       nan      nan          nan
# AACTCCCTCTCAACTT_Ileum-1_Stem Cell       nan      nan          nan
# AACTCTTAGCTTCGCG_Ileum-1_Stem Cell       nan      nan          nan
# ...                                      ...      ...          ...
# TTTGTCAGTAAGGATT-1-4918STDY7714150  SmallInt   3636.0     22.45515
# TTTGTCAGTAGAGGAA-1-4918STDY7714150  SmallInt   2822.0     48.91708
# TTTGTCAGTCTAGAGG-1-4918STDY7714150  SmallInt   4088.0    20.332708
# TTTGTCAGTTGATTGC-1-4918STDY7714150  SmallInt   3308.0     34.67047
# TTTGTCATCAATCTCT-1-4918STDY7714150  SmallInt   4707.0    30.637403
#
#                                    percent_ribo  Subject
# cell_id
# AACACGTTCTTGCATT_Ileum-1_Stem Cell          nan      nan
# AACCGCGCATGAAGTA_Ileum-1_Stem Cell          nan      nan
# AACTCAGAGCGATCCC_Ileum-1_Stem Cell          nan      nan
# AACTCCCTCTCAACTT_Ileum-1_Stem Cell          nan      nan
# AACTCTTAGCTTCGCG_Ileum-1_Stem Cell          nan      nan
# ...                                         ...      ...
# TTTGTCAGTAAGGATT-1-4918STDY7714150     13.80638  T036POS
# TTTGTCAGTAGAGGAA-1-4918STDY7714150     7.583274  T036POS
# TTTGTCAGTCTAGAGG-1-4918STDY7714150    18.542074  T036POS
# TTTGTCAGTTGATTGC-1-4918STDY7714150      4.74607  T036POS
# TTTGTCATCAATCTCT-1-4918STDY7714150    5.4599533  T036POS
#
# [116562 rows x 24 columns]

# %%
reference.obs['seed_labels'] = reference.obs['CellType'].copy()

# %% [markdown]
# ### Read query object

# %%
query_input = '/lustre/groups/talaveralopez/workspace/anna.maguza/Processed_datasets/expi_map/Query_map_after_geosketch2_less_plasma.h5ad'
query_output = '/lustre/groups/talaveralopez/workspace/anna.maguza/Processed_datasets/expi_map/Query_map_after_geosketch2_less_plasma_output.h5ad'

# %%
query = sc.read_h5ad(query_input)
query.X
# Out:
# <258731x40144 sparse matrix of type '<class 'numpy.float32'>'
# 	with 411500554 stored elements in Compressed Sparse Row format>

# %%
query.obs['seed_labels'] = 'Unknown'

# %%
# Concatenate reference and query
adata = reference.concatenate(query, batch_key = 'dataset', batch_categories = ['reference', 'query'])

# %% [markdown]
# ### Select HVGs

# %%
adata_raw = adata.copy()
adata.layers['counts'] = adata.X.copy()

# %% [markdown]
# ### Transfer of annotation with scANVI

# %%
scvi.model.SCVI.setup_anndata(adata, batch_key = 'Sample_ID', labels_key = "seed_labels", layer = 'counts')
# Out:
# WARNING:jax._src.lib.xla_bridge:No GPU/TPU found, falling back to CPU. (Set TF_CPP_MIN_LOG_LEVEL=0 and rerun for more info.)

# %%
scvi_model = scvi.model.SCVI(adata, n_latent = 50, n_layers = 3, dispersion = 'gene-batch', gene_likelihood = 'nb')

# %%
scvi_model.train(100)
# Out:
# GPU available: True (cuda), used: True
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# Epoch 100/100: 100%|█| 100/100 [1:52:49<00:00, 66.63s/it, loss=4.98e+03, v_num=1
# `Trainer.fit` stopped: `max_epochs=100` reached.
# Epoch 100/100: 100%|█| 100/100 [1:52:49<00:00, 67.69s/it, loss=4.98e+03, v_num=1

# %% [markdown]
# ### Label transfer with `scANVI`

# %%
scanvi_model = scvi.model.SCANVI.from_scvi_model(scvi_model, 'Unknown')

# %%
scanvi_model.train(25)
# Out:
# INFO     Training for 25 epochs.
# GPU available: True (cuda), used: True
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# Epoch 25/25: 100%|█████| 25/25 [55:11<00:00, 133.55s/it, loss=5.07e+03, v_num=1]
# `Trainer.fit` stopped: `max_epochs=25` reached.
# Epoch 25/25: 100%|█████| 25/25 [55:11<00:00, 132.47s/it, loss=5.07e+03, v_num=1]

# %%
adata.obs["C_scANVI"] = scanvi_model.predict(adata)

# %% [markdown]
# - Extract latent representation

# %%
adata.obsm["X_scANVI"] = scanvi_model.get_latent_representation(adata)

# %% [markdown]
# - Visualise corrected dataset

# %%
sc.pp.neighbors(adata, use_rep = "X_scANVI", n_neighbors = 50, metric = 'minkowski')
sc.tl.umap(adata, min_dist = 0.2, spread = 2, random_state = 1712)
# Out:
# computing neighbors
#     finished: added to `.uns['neighbors']`
#     `.obsp['distances']`, distances for each pair of neighbors
#     `.obsp['connectivities']`, weighted adjacency matrix (0:02:40)
# computing UMAP
#     finished: added
#     'X_umap', UMAP coordinates (adata.obsm) (0:15:37)

# %%
adata.obs
# Out:
#                                                                    UniqueCell_ID  \
# cell_id
# AACACGTTCTTGCATT_Ileum-1_Stem Cell-reference  AACACGTTCTTGCATT_Ileum-1_Stem Cell
# AACCGCGCATGAAGTA_Ileum-1_Stem Cell-reference  AACCGCGCATGAAGTA_Ileum-1_Stem Cell
# AACTCAGAGCGATCCC_Ileum-1_Stem Cell-reference  AACTCAGAGCGATCCC_Ileum-1_Stem Cell
# AACTCCCTCTCAACTT_Ileum-1_Stem Cell-reference  AACTCCCTCTCAACTT_Ileum-1_Stem Cell
# AACTCTTAGCTTCGCG_Ileum-1_Stem Cell-reference  AACTCTTAGCTTCGCG_Ileum-1_Stem Cell
# ...                                                                          ...
# TTGTAGGTCCCACTTG-1-WTDAtest7770719-query                                     nan
# TTGTAGGTCCTCGCAT-1-WTDAtest7770719-query                                     nan
# TTTATGCCATGTCGAT-1-WTDAtest7770719-query                                     nan
# TTTGCGCTCATGCATG-1-WTDAtest7770719-query                                     nan
# TTTGTCAGTGAAAGAG-1-WTDAtest7770719-query                                     nan
#
#                                                        Sample_ID    CellType  \
# cell_id
# AACACGTTCTTGCATT_Ileum-1_Stem Cell-reference             Ileum-1   Stem Cell
# AACCGCGCATGAAGTA_Ileum-1_Stem Cell-reference             Ileum-1   Stem Cell
# AACTCAGAGCGATCCC_Ileum-1_Stem Cell-reference             Ileum-1   Stem Cell
# AACTCCCTCTCAACTT_Ileum-1_Stem Cell-reference             Ileum-1   Stem Cell
# AACTCTTAGCTTCGCG_Ileum-1_Stem Cell-reference             Ileum-1   Stem Cell
# ...                                                          ...         ...
# TTGTAGGTCCCACTTG-1-WTDAtest7770719-query      A30-SCL-6-SC-45N-2  Epithelial
# TTGTAGGTCCTCGCAT-1-WTDAtest7770719-query      A30-SCL-6-SC-45N-2  Epithelial
# TTTATGCCATGTCGAT-1-WTDAtest7770719-query      A30-SCL-6-SC-45N-2  Epithelial
# TTTGCGCTCATGCATG-1-WTDAtest7770719-query      A30-SCL-6-SC-45N-2  Epithelial
# TTTGTCAGTGAAAGAG-1-WTDAtest7770719-query      A30-SCL-6-SC-45N-2  Epithelial
#
#                                                   Study_name      Diagnosis  \
# cell_id
# AACACGTTCTTGCATT_Ileum-1_Stem Cell-reference            Wang  Healthy adult
# AACCGCGCATGAAGTA_Ileum-1_Stem Cell-reference            Wang  Healthy adult
# AACTCAGAGCGATCCC_Ileum-1_Stem Cell-reference            Wang  Healthy adult
# AACTCCCTCTCAACTT_Ileum-1_Stem Cell-reference            Wang  Healthy adult
# AACTCTTAGCTTCGCG_Ileum-1_Stem Cell-reference            Wang  Healthy adult
# ...                                                      ...            ...
# TTGTAGGTCCCACTTG-1-WTDAtest7770719-query      Gut Cell Atlas  Healthy adult
# TTGTAGGTCCTCGCAT-1-WTDAtest7770719-query      Gut Cell Atlas  Healthy adult
# TTTATGCCATGTCGAT-1-WTDAtest7770719-query      Gut Cell Atlas  Healthy adult
# TTTGCGCTCATGCATG-1-WTDAtest7770719-query      Gut Cell Atlas  Healthy adult
# TTTGTCAGTGAAAGAG-1-WTDAtest7770719-query      Gut Cell Atlas  Healthy adult
#
#                                                 Age Region code Fraction  \
# cell_id
# AACACGTTCTTGCATT_Ileum-1_Stem Cell-reference    nan         nan      nan
# AACCGCGCATGAAGTA_Ileum-1_Stem Cell-reference    nan         nan      nan
# AACTCAGAGCGATCCC_Ileum-1_Stem Cell-reference    nan         nan      nan
# AACTCCCTCTCAACTT_Ileum-1_Stem Cell-reference    nan         nan      nan
# AACTCTTAGCTTCGCG_Ileum-1_Stem Cell-reference    nan         nan      nan
# ...                                             ...         ...      ...
# TTGTAGGTCCCACTTG-1-WTDAtest7770719-query      20-25         SCL   SC-45N
# TTGTAGGTCCTCGCAT-1-WTDAtest7770719-query      20-25         SCL   SC-45N
# TTTATGCCATGTCGAT-1-WTDAtest7770719-query      20-25         SCL   SC-45N
# TTTGCGCTCATGCATG-1-WTDAtest7770719-query      20-25         SCL   SC-45N
# TTTGTCAGTGAAAGAG-1-WTDAtest7770719-query      20-25         SCL   SC-45N
#
#                                              Gender  10X  ...  Location  \
# cell_id                                                   ...
# AACACGTTCTTGCATT_Ileum-1_Stem Cell-reference    nan  nan  ...       nan
# AACCGCGCATGAAGTA_Ileum-1_Stem Cell-reference    nan  nan  ...       nan
# AACTCAGAGCGATCCC_Ileum-1_Stem Cell-reference    nan  nan  ...       nan
# AACTCCCTCTCAACTT_Ileum-1_Stem Cell-reference    nan  nan  ...       nan
# AACTCTTAGCTTCGCG_Ileum-1_Stem Cell-reference    nan  nan  ...       nan
# ...                                             ...  ...  ...       ...
# TTGTAGGTCCCACTTG-1-WTDAtest7770719-query          F   3'  ...  LargeInt
# TTGTAGGTCCTCGCAT-1-WTDAtest7770719-query          F   3'  ...  LargeInt
# TTTATGCCATGTCGAT-1-WTDAtest7770719-query          F   3'  ...  LargeInt
# TTTGCGCTCATGCATG-1-WTDAtest7770719-query          F   3'  ...  LargeInt
# TTTGTCAGTGAAAGAG-1-WTDAtest7770719-query          F   3'  ...  LargeInt
#
#                                              n_counts  percent_mito  \
# cell_id
# AACACGTTCTTGCATT_Ileum-1_Stem Cell-reference      nan           nan
# AACCGCGCATGAAGTA_Ileum-1_Stem Cell-reference      nan           nan
# AACTCAGAGCGATCCC_Ileum-1_Stem Cell-reference      nan           nan
# AACTCCCTCTCAACTT_Ileum-1_Stem Cell-reference      nan           nan
# AACTCTTAGCTTCGCG_Ileum-1_Stem Cell-reference      nan           nan
# ...                                               ...           ...
# TTGTAGGTCCCACTTG-1-WTDAtest7770719-query       3985.0     48.206486
# TTGTAGGTCCTCGCAT-1-WTDAtest7770719-query       1056.0     10.487674
# TTTATGCCATGTCGAT-1-WTDAtest7770719-query      14774.0      6.614223
# TTTGCGCTCATGCATG-1-WTDAtest7770719-query       3369.0  0.0009479364
# TTTGTCAGTGAAAGAG-1-WTDAtest7770719-query      11052.0      5.534037
#
#                                              percent_ribo     Subject  \
# cell_id
# AACACGTTCTTGCATT_Ileum-1_Stem Cell-reference          nan         nan
# AACCGCGCATGAAGTA_Ileum-1_Stem Cell-reference          nan         nan
# AACTCAGAGCGATCCC_Ileum-1_Stem Cell-reference          nan         nan
# AACTCCCTCTCAACTT_Ileum-1_Stem Cell-reference          nan         nan
# AACTCTTAGCTTCGCG_Ileum-1_Stem Cell-reference          nan         nan
# ...                                                   ...         ...
# TTGTAGGTCCCACTTG-1-WTDAtest7770719-query         1.706399  A30 (398B)
# TTGTAGGTCCTCGCAT-1-WTDAtest7770719-query        20.738636  A30 (398B)
# TTTATGCCATGTCGAT-1-WTDAtest7770719-query        27.406254  A30 (398B)
# TTTGCGCTCATGCATG-1-WTDAtest7770719-query        24.220839  A30 (398B)
# TTTGTCAGTGAAAGAG-1-WTDAtest7770719-query        43.847267  A30 (398B)
#
#                                              seed_labels    dataset  \
# cell_id
# AACACGTTCTTGCATT_Ileum-1_Stem Cell-reference   Stem Cell  reference
# AACCGCGCATGAAGTA_Ileum-1_Stem Cell-reference   Stem Cell  reference
# AACTCAGAGCGATCCC_Ileum-1_Stem Cell-reference   Stem Cell  reference
# AACTCCCTCTCAACTT_Ileum-1_Stem Cell-reference   Stem Cell  reference
# AACTCTTAGCTTCGCG_Ileum-1_Stem Cell-reference   Stem Cell  reference
# ...                                                  ...        ...
# TTGTAGGTCCCACTTG-1-WTDAtest7770719-query         Unknown      query
# TTGTAGGTCCTCGCAT-1-WTDAtest7770719-query         Unknown      query
# TTTATGCCATGTCGAT-1-WTDAtest7770719-query         Unknown      query
# TTTGCGCTCATGCATG-1-WTDAtest7770719-query         Unknown      query
# TTTGTCAGTGAAAGAG-1-WTDAtest7770719-query         Unknown      query
#
#                                              _scvi_batch _scvi_labels  \
# cell_id
# AACACGTTCTTGCATT_Ileum-1_Stem Cell-reference         101            8
# AACCGCGCATGAAGTA_Ileum-1_Stem Cell-reference         101            8
# AACTCAGAGCGATCCC_Ileum-1_Stem Cell-reference         101            8
# AACTCCCTCTCAACTT_Ileum-1_Stem Cell-reference         101            8
# AACTCTTAGCTTCGCG_Ileum-1_Stem Cell-reference         101            8
# ...                                                  ...          ...
# TTGTAGGTCCCACTTG-1-WTDAtest7770719-query               4           10
# TTGTAGGTCCTCGCAT-1-WTDAtest7770719-query               4           10
# TTTATGCCATGTCGAT-1-WTDAtest7770719-query               4           10
# TTTGCGCTCATGCATG-1-WTDAtest7770719-query               4           10
# TTTGTCAGTGAAAGAG-1-WTDAtest7770719-query               4           10
#
#                                                 C_scANVI
# cell_id
# AACACGTTCTTGCATT_Ileum-1_Stem Cell-reference  Epithelial
# AACCGCGCATGAAGTA_Ileum-1_Stem Cell-reference  Epithelial
# AACTCAGAGCGATCCC_Ileum-1_Stem Cell-reference  Epithelial
# AACTCCCTCTCAACTT_Ileum-1_Stem Cell-reference  Epithelial
# AACTCTTAGCTTCGCG_Ileum-1_Stem Cell-reference  Epithelial
# ...                                                  ...
# TTGTAGGTCCCACTTG-1-WTDAtest7770719-query      Epithelial
# TTGTAGGTCCTCGCAT-1-WTDAtest7770719-query      Epithelial
# TTTATGCCATGTCGAT-1-WTDAtest7770719-query      Epithelial
# TTTGCGCTCATGCATG-1-WTDAtest7770719-query      Epithelial
# TTTGTCAGTGAAAGAG-1-WTDAtest7770719-query      Epithelial
#
# [375293 rows x 29 columns]

# %%
sc.pl.umap(adata, frameon = False, color = ['C_scANVI', 'CellType', 'dataset', 'Diagnosis', 'Study_name'], size = 0.6, legend_fontsize = 5, ncols = 3)

# %%
#Write anndata object to file
adata.write_h5ad('/lustre/groups/talaveralopez/workspace/anna.maguza/Processed_datasets/expi_map/GCA_Stem_Cell_after_scanvi_less_plasma_cells.h5ad')

# %% [markdown]
# ### Models Validation

# %%
#Read the data
adata_input = '/lustre/groups/talaveralopez/workspace/anna.maguza/Processed_datasets/expi_map/GCA_Stem_Cell_after_scanvi_less_plasma_cells.h5ad'
adata_output = '/lustre/groups/talaveralopez/workspace/anna.maguza/Processed_datasets/expi_map/GCA_Stem_Cell_after_scanvi_less_plasma_cells_output.h5ad'
adata = sc.read_h5ad(adata_input)

# %%
adata.obs['C_scANVI'].value_counts()
# Out:
# Mesenchymal        155759
# Epithelial         136185
# Neuronal            17622
# T cells             17377
# Endothelial         13121
# Plasma cells        12613
# B cells             11413
# Myeloid              9836
# Red blood cells      1367
# Name: C_scANVI, dtype: int64

# %%
adata.obs['CellType'].value_counts()
# Out:
# Mesenchymal        155794
# Epithelial         129929
# Neuronal            17594
# T cells             17394
# Plasma cells        16445
# Endothelial         13082
# B cells             11381
# Myeloid              9820
# Stem Cell            2508
# Red blood cells      1346
# Name: CellType, dtype: int64

# %%
#Validation of the clusters
df = adata.obs.groupby(["CellType", "C_scANVI"]).size().unstack(fill_value=0)
norm_df = df / df.sum(axis=0)

plt.figure(figsize=(8, 8))
_ = plt.pcolor(norm_df)
_ = plt.xticks(np.arange(0.5, len(df.columns), 1), df.columns, rotation=90)
_ = plt.yticks(np.arange(0.5, len(df.index), 1), df.index)
plt.xlabel("Predicted")
plt.ylabel("Observed")
# Out:
# Text(0, 0.5, 'Observed')

# %%
#Calculate accuracy
print(f"Acc: {np.mean(adata.obs.CellType.cat.codes == adata.obs.C_scANVI.cat.codes)}")
# Out:
# Acc: 0.9348429094067835
