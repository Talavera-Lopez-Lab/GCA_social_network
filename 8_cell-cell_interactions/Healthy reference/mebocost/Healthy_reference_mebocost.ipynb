# %% [markdown]
# ## Notebook for CCI-derived metabolism from scRNA-Seq using <span style="color:pink">MEBOCOST</span> in Healthy adult epithelial cells
#
# - **Developed by**: Anna Maguza
# - **Institute of Computational Biology - Computational Health Centre - Helmholtz Munich**
# - 26th of June 2023

# %% [markdown]
# ### Import packages

# %%
import os,sys
import numpy as np
import scanpy as sc
import pandas as pd
import seaborn as sns
from matplotlib import pyplot as plt

from mebocost import mebocost
# Out:
# Warning (xlmhg): Failed to import "mhg_cython" C extension.
# Warning (xlmhg): Failed to import the "mhg_cython" C extension.Falling back to the pure Python implementation, which is very slow.

# %%
sc.settings.verbosity = 3
sc.logging.print_versions()
sc.settings.set_figure_params(dpi = 180, color_map = 'magma_r', dpi_save = 300, vector_friendly = True, format = 'svg')

# %%
def X_is_raw(adata):
    return np.array_equal(adata.X.sum(axis=0).astype(int), adata.X.sum(axis=0))

# %% [markdown]
# ### Data upload

# %%
input = '/Users/anna.maguza/Desktop/Data/Processed_datasets/Cancer_dataset_integration/Datasets integration/healthy_epithelial/Integrated_Healthy_epithelial_datasets_5000.h5ad'
adata = sc.read_h5ad(input)
X_is_raw(adata)

# %%
# Extract the raw counts
adata = adata.raw.to_adata()
adata

# %%
# rename column in adata.obs 'Unified Cell States' to 'Unified_Cell_States' 
adata.obs.rename(columns = {'Unified Cell States': 'Unified_Cell_States'}, inplace = True)

# %% [markdown]
# #### Extract Highly Variable Genes

# %%
adata.layers['counts'] = adata.X.copy()

sc.pp.highly_variable_genes(
    adata,
    flavor = "seurat_v3",
    n_top_genes = 7000,
    layer = "counts",
    batch_key = "Library_Preparation_Protocol",
    subset = True
)

# %% [markdown]
# #### Infer metabolic communications

# %% [markdown]
# - The mebocost.conf file needs to be provided. It is in the original repo and after installation it will have the correct paths and should work out of the box. You could provide the full path to the file, or create a symlink.

# %%
mebo_obj = mebocost.create_obj(
                        adata = adata,
                        group_col = ['Unified_Cell_States'],
                        met_est = 'mebocost',
                        config_path = '/Users/anna.maguza/MEBOCOST/mebocost.conf',
                        exp_mat = None,
                        cell_ann = None,
                        species = 'human',
                        met_pred = None,
                        met_enzyme = None,
                        met_sensor = None,
                        met_ann = None,
                        scFEA_ann = None,
                        compass_met_ann = None,
                        compass_rxn_ann = None,
                        gene_network = None,
                        gmt_path = None,
                        cutoff_exp = 'auto', ## automated cutoff to exclude lowly ranked 25% sensors across all cells
                        cutoff_met = 'auto', ## automated cutoff to exclude lowly ranked 25% metabolites across all cells
                        cutoff_prop = 0.25, ## at lease 25% of cells should be expressed the sensor or present the metabolite in the cell group (specified by group_col)
                        sensor_type = ['Receptor', 'Transporter', 'Nuclear Receptor'],
                        thread = 4
                        )

# %% [markdown]
# #### Estimate metabolite presence

# %% [markdown]
# - If you just want the table of metabolic activity, you can stop here and export it as a CSV file.

# %%
mebo_obj._load_config_()
mebo_obj.estimator()
# Out:
# [April 27, 2023 12:12:11]: Load config and read data based on given species [human].
# [April 27, 2023 12:12:13]: Estimtate metabolite level using mebocost

# %%
met_mat = pd.DataFrame(mebo_obj.met_mat.toarray(),
                      index = mebo_obj.met_mat_indexer,
                      columns = mebo_obj.met_mat_columns)
met_mat.head()
# Out:
#              711539-ST09_CSE_IAV-V1  712557-ST09_CSE_IAV-V1  \
# HMDB0001188                     2.0                     1.0
# HMDB0000699                     0.0                     0.0
# HMDB0006875                     0.0                     0.0
# HMDB0000972                     2.0                     5.0
# HMDB0004673                     0.0                     0.0
#
#              548541-ST09_CSE_IAV-V1  235387-ST09_CSE_IAV-V1  \
# HMDB0001188                     8.0                     3.0
# HMDB0000699                     0.0                     0.0
# HMDB0006875                     0.0                     0.0
# HMDB0000972                     5.0                     0.0
# HMDB0004673                     0.0                     0.0
#
#              843167-ST09_CSE_IAV-V1  429761-ST09_CSE_IAV-V1  \
# HMDB0001188                     8.0                     2.0
# HMDB0000699                     0.0                     0.0
# HMDB0006875                     0.0                     0.0
# HMDB0000972                    11.0                     0.0
# HMDB0004673                     0.0                     0.0
#
#              180538-ST09_CSE_IAV-V1  877284-ST09_CSE_IAV-V1  \
# HMDB0001188                     0.0                     1.0
# HMDB0000699                     0.0                     0.0
# HMDB0006875                     0.0                     0.0
# HMDB0000972                     4.0                     8.0
# HMDB0004673                     0.0                     0.0
#
#              719369-ST09_CSE_IAV-V1  808473-ST09_CSE_IAV-V1  ...  \
# HMDB0001188                     6.0                     0.0  ...
# HMDB0000699                     0.0                     0.0  ...
# HMDB0006875                     0.0                     0.0  ...
# HMDB0000972                     0.0                     7.0  ...
# HMDB0004673                     0.0                     0.0  ...
#
#              7998788-CSE03_CTRL-V6  1633943-CSE03_CTRL-V6  \
# HMDB0001188                    0.0                    0.0
# HMDB0000699                    0.0                    0.0
# HMDB0006875                    0.0                    0.0
# HMDB0000972                    6.0                    0.0
# HMDB0004673                    0.0                    0.0
#
#              13157829-CSE03_CTRL-V6  5759657-CSE03_CTRL-V6  \
# HMDB0001188                     4.0                    0.0
# HMDB0000699                     0.0                    0.0
# HMDB0006875                     0.0                    0.0
# HMDB0000972                     0.0                    0.0
# HMDB0004673                     0.0                    0.0
#
#              2825919-CSE03_CTRL-V6  9600822-CSE03_CTRL-V6  \
# HMDB0001188                    3.0                    4.0
# HMDB0000699                    0.0                    0.0
# HMDB0006875                    0.0                    0.0
# HMDB0000972                    0.0                    0.0
# HMDB0004673                    0.0                    0.0
#
#              12250460-CSE03_CTRL-V6  3863124-CSE03_CTRL-V6  \
# HMDB0001188                     0.0                    0.0
# HMDB0000699                     0.0                    0.0
# HMDB0006875                     0.0                    0.0
# HMDB0000972                     0.0                    0.0
# HMDB0004673                     0.0                    0.0
#
#              4148054-CSE03_CTRL-V6  4291292-CSE03_CTRL-V6
# HMDB0001188                    0.0                    0.0
# HMDB0000699                    0.0                    0.0
# HMDB0006875                    0.0                    0.0
# HMDB0000972                    0.0                    0.0
# HMDB0004673                    0.0                    0.0
#
# [5 rows x 26261 columns]

# %% [markdown]
# #### MEBOCOST cell-cell communication inference

# %%
commu_res = mebo_obj.infer_commu(
                                n_shuffle = 1000,
                                seed = 1712, 
                                Return = True, 
                                thread = 4,
                                save_permuation = False,
                                min_cell_number = 3
: Normalizing Cluster Mean and Calculating Communication Score
# [April 27, 2023 12:14:29]: Calculating P-value
# [April 27, 2023 12:14:31]: RORB ~ HMDB0000067
# [April 27, 2023 12:14:31]: Normalizing Cluster Mean and Calculating Communication Score
# [April 27, 2023 12:14:31]: Calculating P-value
# [April 27, 2023 12:14:33]: Calculating aboundance of metabolite and sensor expression in cell groups
# [April 27, 2023 12:14:33]: automated cutoff for sensor expression, cutoff=2.0
# [April 27, 2023 12:14:35]: automated cutoff for metabolite presence, cutoff=1.0
# [April 27, 2023 12:14:35]: cutoff_exp: 2.0
# [April 27, 2023 12:14:43]: cutoff_metabolite: 1.0
# [April 27, 2023 12:14:54]: Set p value and fdr to 1 if sensor or metaboltie expressed cell proportion less than 0.25
# [April 27, 2023 12:14:54]: Prediction Done in 142.1366 seconds
# [April 27, 2023 12:14:54]: Memory Usage in Peak 1.26 GB

# %%
print('sensor_exp cutoff: %s'%mebo_obj.cutoff_exp)
print('metabolite_presence cutoff: %s'%mebo_obj.cutoff_met)
# Out:
# sensor_exp cutoff: 2.0
# metabolite_presence cutoff: 1.0

# %%
# Save results
commu_res.to_csv('/Users/anna.maguza/Desktop/GCA_healthy_epithelial.csv')

# %% [markdown]
# #### Visualise MEBOCOST prediction

# %% [markdown]
# - Showing the detailed communications (sender-receiver vs metabolite-sensor) in a dot map

# %%
mebo_obj.commu_dotmap(
                sender_focus = ['Stem Cells'],
                metabolite_focus = [],
                sensor_focus = [],
                receiver_focus = [],
                and_or = 'and',
                pval_method = 'permutation_test_fdr',
                pval_cutoff = 0.05,
                figsize = 'auto',
                cmap = 'plasma_r',
                node_size_norm = (10, 150),
                save = None,
                show_plot = True,
                comm_score_col = 'Commu_Score',
                comm_score_cutoff = 0,
                swap_axis = False,
                return_fig = False
                )

# %%
mebo_obj.FlowPlot(
                pval_method = 'permutation_test_fdr',
                pval_cutoff = 0.05,
                sender_focus = ['Stem Cells'],
                metabolite_focus = ['Dehydroascorbic acid'],
                sensor_focus = [],
                receiver_focus = [],
                remove_unrelevant = False,
                and_or = 'and',
                node_label_size = 8,
                node_alpha = 0.6,
                figsize = 'auto',
                node_cmap = 'tab20',
                line_cmap = 'bwr',
                line_vmin = None,
                line_vmax = 15.5,
                node_size_norm = (20, 150),
                linewidth_norm = (0.5, 5),
                save = None,
                show_plot = True,
                comm_score_col = 'Commu_Score',
                comm_score_cutoff = 0,
                text_outline = False,
                return_fig = False
            )

# %%
commu_df = mebo_obj.commu_res.copy()
good_met = commu_df[(commu_df['permutation_test_fdr']<=0.05)]['Metabolite_Name'].sort_values().unique()

mebo_obj.violin_plot(
                    sensor_or_met = good_met[:5], ## only top 5 as example
                    cell_focus = ['Stem Cells'],
                    cmap = 'RdPu',
                    vmin = None,
                    vmax = None,
                    figsize = 'auto',
                    cbar_title = '',
                    save = None,
                    show_plot = True
                    )

# %%
good_sensor = commu_df[(commu_df['permutation_test_fdr']<=0.05)]['Sensor'].sort_values().unique()

mebo_obj.violin_plot(
                    sensor_or_met = good_sensor[:5],## only top 5 as example
                    cell_focus = ['Stem Cells'],
                    cmap = 'RdPu',
                    vmin = None,
                    vmax = None,
                    figsize = 'auto',
                    cbar_title = '',
                    save = None,
                    show_plot = True
                    )
