# %% [markdown]
# ## Notebook for exploratory analysis of Human Gut Stem cells scRNA-Seq `leiden` clustering optimization
#
# - **Developed by**: Anna Maguza
# - **Institute of Computational Biology - Computational Health Centre - Helmholtz Munich**
# - v230407

# %% [markdown]
# ### Load required modules

# %%
import scanpy as sc
import anndata
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
import SCCAF
from SCCAF import SCCAF_assessment, plot_roc

# %%
# %matplotlib inline
matplotlib.rcParams["pdf.fonttype"] = 42
matplotlib.rcParams["ps.fonttype"] = 42

# %%
sc.settings.verbosity = 3
sc.logging.print_versions()
sc.settings.set_figure_params(dpi = 180, color_map = 'magma_r', dpi_save = 300, vector_friendly = True, format = 'svg')
# Out:
# -----
# anndata     0.8.0
# scanpy      1.9.2
# -----
# PIL                         9.4.0
# absl                        NA
# appnope                     0.1.2
# asttokens                   NA
# attr                        22.2.0
# backcall                    0.2.0
# beta_ufunc                  NA
# binom_ufunc                 NA
# brotli                      NA
# certifi                     2022.12.07
# cffi                        1.15.1
# charset_normalizer          2.1.1
# chex                        0.1.7
# colorama                    0.4.6
# comm                        0.1.2
# contextlib2                 NA
# cycler                      0.10.0
# cython_runtime              NA
# dateutil                    2.8.2
# debugpy                     1.5.1
# decorator                   5.1.1
# defusedxml                  0.7.1
# docrep                      0.3.2
# entrypoints                 0.4
# etils                       1.1.1
# executing                   0.8.3
# ...

# %%
def X_is_raw(adata):
    return np.array_equal(adata.X.sum(axis=0).astype(int), adata.X.sum(axis=0))

# %%
input = '/Users/anna.maguza/Desktop/Data/Processed_datasets/Predicted_stem_cells/Predicted_stem_cells_post_leiden.h5ad'
gut_stem = sc.read_h5ad(input)

# %% [markdown]
# ### Resolution 0.1

# %%
sc.tl.leiden(gut_stem, resolution = 0.1, random_state = 1786)
# Out:
# running Leiden clustering
#     finished: found 3 clusters and added
#     'leiden', the cluster labels (adata.obs, categorical) (0:00:03)

# %%
sc.set_figure_params(figsize=(5, 5),dpi=60)
y_prob, y_pred, y_test, clf, cvsm, acc = SCCAF_assessment(gut_stem.X, gut_stem.obs['leiden'], n = 100)
plot_roc(y_prob, y_test, clf, cvsm = cvsm, acc = acc)
plt.show()
# Out:
# Mean CV accuracy: 0.8167
# Accuracy on the training set: 1.0000
# Accuracy on the hold-out set: 0.8428

# %% [markdown]
# ### Resolution 0.2

# %%
sc.tl.leiden(gut_stem, resolution = 0.2, random_state = 1786)
# Out:
# running Leiden clustering
#     finished: found 5 clusters and added
#     'leiden', the cluster labels (adata.obs, categorical) (0:00:02)

# %%
sc.set_figure_params(figsize=(5, 5),dpi=60)
y_prob, y_pred, y_test, clf, cvsm, acc = SCCAF_assessment(gut_stem.X, gut_stem.obs['leiden'], n = 100)
plot_roc(y_prob, y_test, clf, cvsm = cvsm, acc = acc)
plt.show()
# Out:
# Mean CV accuracy: 0.7420
# Accuracy on the training set: 1.0000
# Accuracy on the hold-out set: 0.7256

# %% [markdown]
# ### Resolution 0.3

# %%
sc.tl.leiden(gut_stem, resolution = 0.3, random_state = 1786)
# Out:
# running Leiden clustering
#     finished: found 6 clusters and added
#     'leiden', the cluster labels (adata.obs, categorical) (0:00:05)

# %%
sc.set_figure_params(figsize=(5, 5),dpi=60)
y_prob, y_pred, y_test, clf, cvsm, acc = SCCAF_assessment(gut_stem.X, gut_stem.obs['leiden'], n = 100)
plot_roc(y_prob, y_test, clf, cvsm = cvsm, acc = acc)
plt.show()
# Out:
# Mean CV accuracy: 0.7117
# Accuracy on the training set: 1.0000
# Accuracy on the hold-out set: 0.6899

# %% [markdown]
# ### Resolution 0.4

# %%
sc.tl.leiden(gut_stem, resolution = 0.4, random_state = 1786)
# Out:
# running Leiden clustering
#     finished: found 8 clusters and added
#     'leiden', the cluster labels (adata.obs, categorical) (0:00:04)

# %%
sc.set_figure_params(figsize=(5, 5),dpi=60)
y_prob, y_pred, y_test, clf, cvsm, acc = SCCAF_assessment(gut_stem.X, gut_stem.obs['leiden'], n = 100)
plot_roc(y_prob, y_test, clf, cvsm = cvsm, acc = acc)
plt.show()
# Out:
# Mean CV accuracy: 0.6300
# Accuracy on the training set: 1.0000
# Accuracy on the hold-out set: 0.6337

# %% [markdown]
# ### Resolution 0.5

# %%
sc.tl.leiden(gut_stem, resolution = 0.5, random_state = 1786)
# Out:
# running Leiden clustering
#     finished: found 12 clusters and added
#     'leiden', the cluster labels (adata.obs, categorical) (0:00:07)

# %%
sc.set_figure_params(figsize=(5, 5),dpi=60)
y_prob, y_pred, y_test, clf, cvsm, acc = SCCAF_assessment(gut_stem.X, gut_stem.obs['leiden'], n = 100)
plot_roc(y_prob, y_test, clf, cvsm = cvsm, acc = acc)
plt.show()
# Out:
# Mean CV accuracy: 0.5617
# Accuracy on the training set: 1.0000
# Accuracy on the hold-out set: 0.5683

# %% [markdown]
# ### Resolution 0.6

# %%
sc.tl.leiden(gut_stem, resolution = 0.6, random_state = 1786)
# Out:
# running Leiden clustering
#     finished: found 12 clusters and added
#     'leiden', the cluster labels (adata.obs, categorical) (0:00:04)

# %%
sc.set_figure_params(figsize=(5, 5),dpi=60)
y_prob, y_pred, y_test, clf, cvsm, acc = SCCAF_assessment(gut_stem.X, gut_stem.obs['leiden'], n = 100)
plot_roc(y_prob, y_test, clf, cvsm = cvsm, acc = acc)
plt.show()
# Out:
# Mean CV accuracy: 0.5467
# Accuracy on the training set: 1.0000
# Accuracy on the hold-out set: 0.5772

# %% [markdown]
# ### Resolution 0.7

# %%
sc.tl.leiden(gut_stem, resolution = 0.7, random_state = 1786)
# Out:
# running Leiden clustering
#     finished: found 14 clusters and added
#     'leiden', the cluster labels (adata.obs, categorical) (0:00:03)

# %%
sc.set_figure_params(figsize=(5, 5),dpi=60)
y_prob, y_pred, y_test, clf, cvsm, acc = SCCAF_assessment(gut_stem.X, gut_stem.obs['leiden'], n = 100)
plot_roc(y_prob, y_test, clf, cvsm = cvsm, acc = acc)
plt.show()
# Out:
# Mean CV accuracy: 0.5050
# Accuracy on the training set: 1.0000
# Accuracy on the hold-out set: 0.5371

# %% [markdown]
# ### Resolution 0.8

# %%
sc.tl.leiden(gut_stem, resolution = 0.8, random_state = 1786)
# Out:
# running Leiden clustering
#     finished: found 15 clusters and added
#     'leiden', the cluster labels (adata.obs, categorical) (0:00:03)

# %%
sc.set_figure_params(figsize=(5, 5),dpi=60)
y_prob, y_pred, y_test, clf, cvsm, acc = SCCAF_assessment(gut_stem.X, gut_stem.obs['leiden'], n = 100)
plot_roc(y_prob, y_test, clf, cvsm = cvsm, acc = acc)
plt.show()
# Out:
# Mean CV accuracy: 0.5333
# Accuracy on the training set: 1.0000
# Accuracy on the hold-out set: 0.5248

# %% [markdown]
# ### Resolution 0.9

# %%
sc.tl.leiden(gut_stem, resolution = 0.9, random_state = 1786)
# Out:
# running Leiden clustering
#     finished: found 16 clusters and added
#     'leiden', the cluster labels (adata.obs, categorical) (0:00:06)

# %%
sc.set_figure_params(figsize=(5, 5),dpi=60)
y_prob, y_pred, y_test, clf, cvsm, acc = SCCAF_assessment(gut_stem.X, gut_stem.obs['leiden'], n = 100)
plot_roc(y_prob, y_test, clf, cvsm = cvsm, acc = acc)
plt.show()
# Out:
# Mean CV accuracy: 0.4969
# Accuracy on the training set: 1.0000
# Accuracy on the hold-out set: 0.5265

# %% [markdown]
# ### Resolution 1

# %%
sc.tl.leiden(gut_stem, resolution = 1, random_state = 1786)
# Out:
# running Leiden clustering
#     finished: found 16 clusters and added
#     'leiden', the cluster labels (adata.obs, categorical) (0:00:04)

# %%
sc.set_figure_params(figsize=(15, 15),dpi=60)
y_prob, y_pred, y_test, clf, cvsm, acc = SCCAF_assessment(gut_stem.X, gut_stem.obs['leiden'], n = 100)
plot_roc(y_prob, y_test, clf, cvsm = cvsm, acc = acc)
plt.show()
# Out:
# Mean CV accuracy: 0.5087
# Accuracy on the training set: 1.0000
# Accuracy on the hold-out set: 0.5246
